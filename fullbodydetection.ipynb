# %% [markdown]
# <a href="https://colab.research.google.com/github/PRAN20/Full-Body-Detection/blob/main/fullbodydetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mediapipe --quiet
# !pip install jovian --quiet
# Out:
#      |████████████████████████████████| 32.7 MB 1.4 MB/s
#      |████████████████████████████████| 68 kB 2.8 MB/s
#   Building wheel for uuid (setup.py) ... done

# %%
import cv2                  
import mediapipe as mp    
import jovian               
import time                 
import plotly.express as px

# %%
image = cv2.imread("/content/MG_7574-1.jpg")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.title("Test Image")

plt.imshow(image)
plt.show()

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# %%
mp_drawing.DrawingSpec(color = (255,255,0),thickness = 1.5, circle_radius=1.5)
# Out:
# DrawingSpec(color=(255, 255, 0), thickness=1.5, circle_radius=1.5)

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.title("Test Image")

plt.imshow(image)
plt.show()

# %%
image = cv2.flip(image,1)

# %%
with mp_holistic.Holistic(min_detection_confidence = 0.5, min_tracking_confidence = 0.5) as holistic:
  results = holistic.process(image)

# %%
print(results)
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.title("Test Image")

plt.imshow(image)
plt.show()

# %%
mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
  mp_drawing.DrawingSpec(color = (255,255,0),thickness = 2, circle_radius=2),
  mp_drawing.DrawingSpec(color = (255,255,0),thickness = 2, circle_radius=2))

# %%
mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
  mp_drawing.DrawingSpec(color = (150,255,0),thickness = 2, circle_radius=2),
  mp_drawing.DrawingSpec(color = (150,255,0),thickness = 2, circle_radius=2))

# %%
mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
  mp_drawing.DrawingSpec(color = (150,255,0),thickness = 2, circle_radius=2),
  mp_drawing.DrawingSpec(color = (150,255,0),thickness = 2, circle_radius=2))

# %%
mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
 mp_drawing.DrawingSpec(color = (255,0,255),thickness = 2, circle_radius=2),
 mp_drawing.DrawingSpec(color = (255,0,255),thickness = 2, circle_radius=2))

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.title("Test Image")

plt.imshow(image)
plt.savefig("Result.png")
plt.show()
